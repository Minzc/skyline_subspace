# %%
from operator import itemgetter, attrgetter
f = open('C:\\scratch\\jiaxingl\\AMiner-Author\\AMiner-Author.txt', 'r')
s = f.read().split('\n\n')
c_count = {}
for author in s:
    x = author.split('\n')
    a_list = []
    for i in x:
        if len(i) < 3: continue
        if i[1] == 't':
            for field in i[3:].split():
                c_count[field] = c_count.get(field, 0) + 1
c_count.iteritems()
# Out:
# 25370

# %%
print c_count
# Out:
# {'J;m': 1, 'J;n': 1, 'J;k': 1, 'q-1': 1, 'q-0': 1, 'S-2': 1, 'S-1': 1, 'Dagu': 1, 'BSDT': 1, 'LASS': 1, 'OPAC': 1, 'OPAL': 1, 'HDF5': 1, 'OPAH': 1, 'LASE': 1, 'LASI': 1, 'Euro': 1, 'q-q': 1, 'Elen': 1, 'Eles': 1, 'Y14': 1, 'PQD': 1, 'S-W': 1, 'S-V': 1, 'Loeb': 1, 'S-T': 1, 'S-R': 1, 'S-P': 1, 'S-N': 1, 'PQR': 1, 'S-I': 1, 'S-H': 1, 'S-G': 1, 'S-D': 1, 'S-C': 1, 'S-B': 1, 'S-A': 1, 'Hrms': 1, 'RF;R': 1, 'OSAP': 1, 'OSAS': 1, 'BIRT': 1, 'OSAF': 1, 'BIRN': 1, 'BIRA': 1, 'Agfa': 1, 'BIRD': 1, 'MurO': 1, 'MurC': 1, 'EIRP': 1, '1-TV': 1, 'Mura': 1, 'ERGA': 1, 'ERGO': 1, 'EEsA': 1, 'p47': 1, 'ARTP': 1, 'ARTS': 1, 'dna': 1, 'CFST': 1, 'RRep': 1, 'ART1': 1, 'ART2': 1, 'TDCA': 1, 'TDCS': 1, 'Buoy': 1, 'RLM': 1, 'RLL': 1, 'RLI': 1, 'RLE': 1, 'RLG': 1, 'RLA': 1, 'RLC': 1, 'RLX': 1, 'RLT': 1, 'RLW': 1, 'RLP': 1, 'RLS': 1, 'RLR': 1, 'ABAC': 1, 'Le': 1, 'wand': 1, 'La': 1, 'Ln': 1, 'Lo': 1, 'Lk': 1, 'Li': 1, 'wans': 1, 'ABAP': 1, 'Lu': 1, 'Lr': 1, 'Ls': 1, 'Lp': 1, 'Lq': 1, 'CF4': 1, 'Lx': 1, 'Ly':
# ...
